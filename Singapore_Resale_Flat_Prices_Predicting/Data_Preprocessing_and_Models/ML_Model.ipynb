# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing and Reading Combined Data

# %%
df = pd.read_csv('combined.csv')
df
# Out:
#         latitude   longitude blk_no             road_name  postal_code  \
# 0       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 1       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 2       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 3       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 4       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# ...          ...         ...    ...                   ...          ...
# 202178  1.355461  103.937119   860B     TAMPINES AVENUE 5       522860
# 202179  1.439166  103.779977    121        MARSILING RISE       730121
# 202180  1.421422  103.839249    659       YISHUN AVENUE 4       760659
# 202181  1.377148  103.774024    271          BANGKIT ROAD       670271
# 202182  1.307646  103.860269    802           FRENCH ROAD       200802
#
#                       address      cbd_dist  min_dist_mrt    month  \
# 0       406 ANG MO KIO AVE 10   8740.633473    999.941595  2017-01
# 1       406 ANG MO KIO AVE 10   8740.633473    999.941595  2017-05
# 2       406 ANG MO KIO AVE 10   8740.633473    999.941595  2018-03
# 3       406 ANG MO KIO AVE 10   8740.633473    999.941595  2018-03
# 4       406 ANG MO KIO AVE 10   8740.633473    999.941595  2018-05
# ...                       ...           ...           ...      ...
# 202178    860B TAMPINES AVE 5  12466.578115   1097.338326  2016-09
# 202179     121 MARSILING RISE  19004.920891    950.372898  2016-10
# 202180       659 YISHUN AVE 4  15364.619802    828.374098  2016-10
# 202181         271 BANGKIT RD  13503.256987   1339.847514  2016-11
# 202182          802 FRENCH RD   2902.265148    279.630252  2016-11
#
#                    town  flat_type block        street_name storey_range  \
# 0            ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1            ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 2            ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     01 TO 03
# 3            ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     01 TO 03
# 4            ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     07 TO 09
# ...                 ...        ...   ...                ...          ...
# 202178         TAMPINES     4 ROOM  860B     TAMPINES AVE 5     04 TO 06
# 202179        WOODLANDS  EXECUTIVE   121     MARSILING RISE     04 TO 06
# 202180           YISHUN     4 ROOM   659       YISHUN AVE 4     04 TO 06
# 202181    BUKIT PANJANG     5 ROOM   271         BANGKIT RD     04 TO 06
# 202182  KALLANG/WHAMPOA     3 ROOM   802          FRENCH RD     04 TO 06
#
#         floor_area_sqm  flat_model  lease_commence_date  resale_price  \
# 0                 44.0    Improved                 1979      232000.0
# 1                 44.0    Improved                 1979      235000.0
# 2                 44.0    Improved                 1979      202000.0
# 3                 44.0    Improved                 1979      210000.0
# 4                 44.0    Improved                 1979      220000.0
# ...                ...         ...                  ...           ...
# 202178           104.0     Model A                 1987      460000.0
# 202179           170.0   Apartment                 1995      670000.0
# 202180            89.0  Simplified                 1987      335000.0
# 202181           122.0    Improved                 1988      425000.0
# 202182            59.0    Improved                 1979      328000.0
#
#            remaining_lease  lease_remain_years
# 0       61 years 04 months                  55
# 1        61 years 01 month                  55
# 2       60 years 02 months                  55
# 3       60 years 02 months                  55
# 4        60 years 01 month                  55
# ...                    ...                 ...
# 202178                  70                  63
# 202179                  77                  71
# 202180                  69                  63
# 202181                  70                  64
# 202182                  61                  55
#
# [202183 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code              int64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %% [markdown]
# # Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no             road_name  postal_code  \
# 0       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 1       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 2       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 3       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# 4       1.362005  103.853880    406  ANG MO KIO AVENUE 10       560406
# ...          ...         ...    ...                   ...          ...
# 202178  1.355461  103.937119   860B     TAMPINES AVENUE 5       522860
# 202179  1.439166  103.779977    121        MARSILING RISE       730121
# 202180  1.421422  103.839249    659       YISHUN AVENUE 4       760659
# 202181  1.377148  103.774024    271          BANGKIT ROAD       670271
# 202182  1.307646  103.860269    802           FRENCH ROAD       200802
#
#                       address      cbd_dist  min_dist_mrt    month  \
# 0       406 ANG MO KIO AVE 10   8740.633473    999.941595  2017-01
# 1       406 ANG MO KIO AVE 10   8740.633473    999.941595  2017-05
# 2       406 ANG MO KIO AVE 10   8740.633473    999.941595  2018-03
# 3       406 ANG MO KIO AVE 10   8740.633473    999.941595  2018-03
# 4       406 ANG MO KIO AVE 10   8740.633473    999.941595  2018-05
# ...                       ...           ...           ...      ...
# 202178    860B TAMPINES AVE 5  12466.578115   1097.338326  2016-09
# 202179     121 MARSILING RISE  19004.920891    950.372898  2016-10
# 202180       659 YISHUN AVE 4  15364.619802    828.374098  2016-10
# 202181         271 BANGKIT RD  13503.256987   1339.847514  2016-11
# 202182          802 FRENCH RD   2902.265148    279.630252  2016-11
#
#                    town  ... block        street_name storey_range  \
# 0            ANG MO KIO  ...   406  ANG MO KIO AVE 10     10 TO 12
# 1            ANG MO KIO  ...   406  ANG MO KIO AVE 10     10 TO 12
# 2            ANG MO KIO  ...   406  ANG MO KIO AVE 10     01 TO 03
# 3            ANG MO KIO  ...   406  ANG MO KIO AVE 10     01 TO 03
# 4            ANG MO KIO  ...   406  ANG MO KIO AVE 10     07 TO 09
# ...                 ...  ...   ...                ...          ...
# 202178         TAMPINES  ...  860B     TAMPINES AVE 5     04 TO 06
# 202179        WOODLANDS  ...   121     MARSILING RISE     04 TO 06
# 202180           YISHUN  ...   659       YISHUN AVE 4     04 TO 06
# 202181    BUKIT PANJANG  ...   271         BANGKIT RD     04 TO 06
# 202182  KALLANG/WHAMPOA  ...   802          FRENCH RD     04 TO 06
#
#        floor_area_sqm  flat_model lease_commence_date  resale_price  \
# 0                44.0    Improved                1979      232000.0
# 1                44.0    Improved                1979      235000.0
# 2                44.0    Improved                1979      202000.0
# 3                44.0    Improved                1979      210000.0
# 4                44.0    Improved                1979      220000.0
# ...               ...         ...                 ...           ...
# 202178          104.0     Model A                1987      460000.0
# 202179          170.0   Apartment                1995      670000.0
# 202180           89.0  Simplified                1987      335000.0
# 202181          122.0    Improved                1988      425000.0
# 202182           59.0    Improved                1979      328000.0
#
#            remaining_lease lease_remain_years  storey_median
# 0       61 years 04 months                 55           11.0
# 1        61 years 01 month                 55           11.0
# 2       60 years 02 months                 55            2.0
# 3       60 years 02 months                 55            2.0
# 4        60 years 01 month                 55            8.0
# ...                    ...                ...            ...
# 202178                  70                 63            5.0
# 202179                  77                 71            5.0
# 202180                  69                 63            5.0
# 202181                  70                 64            5.0
# 202182                  61                 55            5.0
#
# [202183 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0        8740.633473    999.941595            44.0                  55
# 1        8740.633473    999.941595            44.0                  55
# 2        8740.633473    999.941595            44.0                  55
# 3        8740.633473    999.941595            44.0                  55
# 4        8740.633473    999.941595            44.0                  55
# ...              ...           ...             ...                 ...
# 202178  12466.578115   1097.338326           104.0                  63
# 202179  19004.920891    950.372898           170.0                  71
# 202180  15364.619802    828.374098            89.0                  63
# 202181  13503.256987   1339.847514           122.0                  64
# 202182   2902.265148    279.630252            59.0                  55
#
#         storey_median  resale_price
# 0                11.0      232000.0
# 1                11.0      235000.0
# 2                 2.0      202000.0
# 3                 2.0      210000.0
# 4                 8.0      220000.0
# ...               ...           ...
# 202178            5.0      460000.0
# 202179            5.0      670000.0
# 202180            5.0      335000.0
# 202181            5.0      425000.0
# 202182            5.0      328000.0
#
# [202183 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0        8740.633473    999.941595            44.0                  55
# 1        8740.633473    999.941595            44.0                  55
# 2        8740.633473    999.941595            44.0                  55
# 3        8740.633473    999.941595            44.0                  55
# 4        8740.633473    999.941595            44.0                  55
# ...              ...           ...             ...                 ...
# 202178  12466.578115   1097.338326           104.0                  63
# 202179  19004.920891    950.372898           170.0                  71
# 202180  15364.619802    828.374098            89.0                  63
# 202181  13503.256987   1339.847514           122.0                  64
# 202182   2902.265148    279.630252            59.0                  55
#
#         storey_median  resale_price
# 0                11.0      232000.0
# 1                11.0      235000.0
# 2                 2.0      202000.0
# 3                 2.0      210000.0
# 4                 8.0      220000.0
# ...               ...           ...
# 202178            5.0      460000.0
# 202179            5.0      670000.0
# 202180            5.0      335000.0
# 202181            5.0      425000.0
# 202182            5.0      328000.0
#
# [195926 rows x 6 columns]

# %% [markdown]
# # Checking and Handling for Skewness in the Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
                                                                # effect on the data, so no need to apply for that columns
    
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %% [markdown]
# # Visualization among different columns using Correlation Matrix

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <AxesSubplot:title={'center':'Correlation Heatmap'}>

# %% [markdown]
# # Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -0.838453  0.376666 -2.988250 -1.184227  0.655739
# 1      -0.838453  0.376666 -2.988250 -1.184227  0.655739
# 2      -0.838453  0.376666 -2.988250 -1.184227 -1.716952
# 3      -0.838453  0.376666 -2.988250 -1.184227 -1.716952
# 4      -0.838453  0.376666 -2.988250 -1.184227  0.212511
# ...          ...       ...       ...       ...       ...
# 195921  0.007626  0.587602  0.372162 -0.590151 -0.441646
# 195922  1.492339  0.269313  2.291867  0.003924 -0.441646
# 195923  0.665707  0.005095 -0.236299 -0.590151 -0.441646
# 195924  0.243033  1.112814  0.995764 -0.515892 -0.441646
# 195925 -2.164217 -1.183342 -1.842275 -1.184227 -0.441646
#
# [195926 rows x 5 columns]

# %% [markdown]
# # Splitting the Data for Training and Testing Purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 4}
#
# Mean squared error: 0.013992937995985295
# Mean Absolute Error 0.09316986944583869
# Root Mean squared error: 0.1182917494839995
#
# R-squared: 0.8725657279916519

# %% [markdown]
# # Testing Our Trained Model (Decision Tree Regressor)

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 226100.45343841802

# %%
# Saving the model
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
